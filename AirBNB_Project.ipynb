# %%
import pandas as pd
import os.path

# %%
df_cols.loc[df_cols['Files'].str.contains('csv')]
# Out:
#                           Files  File Size (MB)
# 2               listings.csv.gz        0.932583
# 3        listings_Asheville.csv        6.709891
# 4           listings_Austin.csv       25.272316
# 5           listings_Boston.csv        9.063423
# 6   listings_Broward County.csv       29.132234
# 7        listings_Cambridge.csv        2.240993
# 8          listings_Chicago.csv       18.179963
# 9     listings_Clark County.csv       24.450829
# 10        listings_Colombus.csv        3.586148
# 11          listings_Dallas.csv       10.462730
# 12          listings_Denver.csv        9.762857
# 13          listings_Hawaii.csv       68.024691
# 14     listings_Jersey City.csv        3.265589
# 15     listings_Los Angeles.csv       79.754568
# 16     listings_New Orleans.csv       17.421437
# 17   listings_New York City.csv       86.223243
# 18         listings_Oakland.csv        5.828382
# 19   listings_Pacific Grove.csv        0.551775
# 20        listings_Portland.csv       10.880926
# ...

# %%
file_sizes = [os.path.getsize(os.listdir()[x])/1000000 for x in range(len(os.listdir()))]
file_sizes
df_cols = pd.DataFrame({'Files': os.listdir(), 'File Size (MB)': file_sizes})
df_cols = df_cols.loc[df_cols['Files'].str.contains('csv')].reset_index(drop=True)
cwd = os.getcwd()
df_cols
# Out:
#                           Files  File Size (MB)
# 0        listings_Asheville.csv        6.709891
# 1           listings_Austin.csv       25.272316
# 2           listings_Boston.csv        9.063423
# 3   listings_Broward County.csv       29.132234
# 4        listings_Cambridge.csv        2.240993
# 5          listings_Chicago.csv       18.179963
# 6     listings_Clark County.csv       24.450829
# 7         listings_Colombus.csv        3.586148
# 8           listings_Dallas.csv       10.462730
# 9           listings_Denver.csv        9.762857
# 10          listings_Hawaii.csv       68.024691
# 11     listings_Jersey City.csv        3.265589
# 12     listings_Los Angeles.csv       79.754568
# 13     listings_New Orleans.csv       17.421437
# 14   listings_New York City.csv       86.223243
# 15         listings_Oakland.csv        5.828382
# 16   listings_Pacific Grove.csv        0.551775
# 17        listings_Portland.csv       10.880926
# 18    listings_Rhode Island.csv        8.818789
# ...

# %%
pd.read_csv("listings_Asheville.csv")
# Out:
#             id                            listing_url       scrape_id  \
# 0       108061    https://www.airbnb.com/rooms/108061  20210419203214
# 1       155305    https://www.airbnb.com/rooms/155305  20210419203214
# 2       156805    https://www.airbnb.com/rooms/156805  20210419203214
# 3       156926    https://www.airbnb.com/rooms/156926  20210419203214
# 4       160594    https://www.airbnb.com/rooms/160594  20210419203214
# ...        ...                                    ...             ...
# 2328  49232646  https://www.airbnb.com/rooms/49232646  20210419203214
# 2329  49241261  https://www.airbnb.com/rooms/49241261  20210419203214
# 2330  49243841  https://www.airbnb.com/rooms/49243841  20210419203214
# 2331  49255591  https://www.airbnb.com/rooms/49255591  20210419203214
# 2332  49284012  https://www.airbnb.com/rooms/49284012  20210419203214
#
#      last_scraped                                               name  \
# ...
